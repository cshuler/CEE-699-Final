# %%
# %matplotlib notebook
import scipy.optimize as opt


# make the screen bigger!
from IPython.display import display, HTML
display(HTML(data=""" <style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 85%; }
    div#maintoolbar-container { width: 99%; } </style> """))
# Out:
#  <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 85%; }
#     div#maintoolbar-container { width: 99%; } </style>

# %% [markdown]
# # modflow model as a class

# %%
import numpy as np
import flopy
import flopy.utils.binaryfile as bf
import matplotlib.pyplot as plt


class Fin_Mod:
    """
    modflow model for multiple well pumping
    every values are represented as 2D np array
    """
    def __init__(self):


        # Assign name and create modflow model object
        txtname = 'test_no_5.2'
        self.model_name = flopy.modflow.Modflow(txtname, exe_name='mf2005')
        self.txtname = txtname

        dis = flopy.modflow.ModflowDis.load('TutCoast_simple5.dis', self.model_name)       # this command is neededed to load an existing .dis file   (essentially is grid geometry)
        bas = flopy.modflow.ModflowBas.load('TutCoast_simple5.ba6',self.model_name)        #  load an existing .basic package                         (essentially is ibound and starting heads)
        lpf = flopy.modflow.ModflowLpf.load('TutCoast_simple5.lpf', self.model_name)       #  load an existing .lpf file    
        rch = flopy.modflow.ModflowRch.load('TutCoast_simple5.rch', self.model_name)       # load recharge
        hobs = flopy.modflow.ModflowHob.load('TutCoast_simple5.hob', self.model_name)      #  LOad OBS
        

        # Add PCG package to the MODFLOW model
        pcg = flopy.modflow.ModflowPcg(self.model_name)
        
        # Add OC package to the MODFLOW model
        spd = {(0, 0): ['print head', 'print budget', 'save head', 'save budget']}
        oc = flopy.modflow.ModflowOc(self.model_name, stress_period_data=spd, compact=True)
  
     

    def run(self, All_Qs):
        
        # yay here is where we can mess with the well pump rates (this changes all of them at once)
        wel = flopy.modflow.ModflowWel.load('TutCoast_simple5.wel', self.model_name)
                  
        for idx, i in enumerate(wel.stress_period_data[1]):
            wel.stress_period_data[1][idx][3] = All_Qs 
            
                # MODFLOW input
        # Write the MODFLOW model input files
        # If we cannot (over)write input files, try to write until it succeeds
        while True:
            try:
                self.model_name.write_input()
            except OSError as err:
                print("File writing error: %s" % (err))
            else:  # if we succeed, get out of the loop
                break

        # Run the MODFLOW model
        success, buff = self.model_name.run_model(silent=True)

        return success

    
    def head(self):
        """
            minimum head value
        """

        hds = bf.HeadFile(self.txtname + '.hds')
        times = hds.get_times()  # simulation time, steady state
        heads = hds.get_data(totim=times[-1])
        hds.close()  # close the file object for the next run

        return heads
    
    
    def minhead(self):
        """
            minimum head value
        """

        return self.head().min()
    
    
    def plot(self,title="head"):
        fig = plt.figure(figsize=(9, 5))
        ax = fig.add_subplot(1, 1, 1, aspect='equal')

        modelmap = flopy.plot.ModelMap(model=self.model_name, layer=0) # broken fix somehow
        qm = modelmap.plot_ibound()
        lc = modelmap.plot_grid()

        levels = np.linspace(0, self.head().max(), 11)
        cs = modelmap.contour_array(self.head(), levels=levels)
        fig.colorbar(cs)
        plt.title(title)
        plt.show()
        return # return nothing, but function should end with return
    
    def uniquehead(self):
        return np.unique(self.head())

# %%
def optomizo(Q):
    model = Fin_Mod()
    model.run(Q)

    objval = Q

    observations = np.loadtxt('test_no_5.2.hob.out', skiprows=1, usecols=[0,1])
    residuals= []
    for idx, i in enumerate(observations):   
        r = observations[idx][1]-observations[idx][0]
        residuals.append(r)
    top_draw = max(residuals)
    
    rates = np.loadtxt('test_no_5.2.wel', skiprows=3, usecols=3)
    Sum_Q = sum(rates)

    if top_draw > 3:                 # this is where the maximum allwable drawdown is defined
        penalty = 100000* (top_draw + 1.0) ** 4               # this is where the penalty for exceeding maximum allwable drawdown is defined        
    else: 
        penalty = 0

    cost_ben = Sum_Q + penalty
    
    print("pumpting rate: %f, penalty : %f, objval: %f" % (Q, penalty, cost_ben))
    
    return cost_ben

# Use Nelder-Mead/Simplex method for this problem
results = opt.minimize(optomizo, x0=-1000.,method="Nelder-Mead",tol = 1.)

Good_Q = float(results['final_simplex'][0][0])
Fin_Mod().run(Good_Q)
Fin_Mod().plot()

print("Water obtained is  {} cubic m per day, with max drawdown of  3 m".format(Good_Q, ))
# Out:
# pumpting rate: -1000.000000, penalty : 0.000000, objval: -62000.000000
# pumpting rate: -1050.000000, penalty : 0.000000, objval: -65100.000000
# pumpting rate: -1100.000000, penalty : 0.000000, objval: -68200.000000
# pumpting rate: -1150.000000, penalty : 0.000000, objval: -71300.000000
# pumpting rate: -1250.000000, penalty : 0.000000, objval: -77500.000000
# pumpting rate: -1350.000000, penalty : 0.000000, objval: -83700.000000
# pumpting rate: -1550.000000, penalty : 0.000000, objval: -96100.000000
# pumpting rate: -1750.000000, penalty : 0.000000, objval: -108500.000000
# pumpting rate: -2150.000000, penalty : 27826883.644132, objval: 27693583.644132
# pumpting rate: -1550.000000, penalty : 0.000000, objval: -96100.000000
# pumpting rate: -1950.000000, penalty : 0.000000, objval: -120900.000000
# pumpting rate: -2150.000000, penalty : 27826883.644132, objval: 27693583.644132
# pumpting rate: -2150.000000, penalty : 27826883.644132, objval: 27693583.644132
# pumpting rate: -1850.000000, penalty : 0.000000, objval: -114700.000000
# pumpting rate: -2050.000000, penalty : 0.000000, objval: -127100.000000
# pumpting rate: -2150.000000, penalty : 27826883.644132, objval: 27693583.644132
# pumpting rate: -2150.000000, penalty : 27826883.644132, objval: 27693583.644132
# pumpting rate: -2000.000000, penalty : 0.000000, objval: -124000.000000
# pumpting rate: -2100.000000, penalty : 25918393.237398, objval: 25788193.237398
# pumpting rate: -2025.000000, penalty : 0.000000, objval: -125550.000000
# pumpting rate: -2075.000000, penalty : 0.000000, objval: -128650.000000
# pumpting rate: -2100.000000, penalty : 25918393.237398, objval: 25788193.237398
# pumpting rate: -2100.000000, penalty : 25918393.237398, objval: 25788193.237398
# pumpting rate: -2062.500000, penalty : 0.000000, objval: -127875.000000
# pumpting rate: -2087.500000, penalty : 0.000000, objval: -129425.000000
# pumpting rate: -2100.000000, penalty : 25918393.237398, objval: 25788193.237398
# pumpting rate: -2100.000000, penalty : 25918393.237398, objval: 25788193.237398
# pumpting rate: -2081.250000, penalty : 0.000000, objval: -129037.500000
# pumpting rate: -2093.750000, penalty : 25686945.232529, objval: 25557132.732529
# pumpting rate: -2084.375000, penalty : 0.000000, objval: -129231.250000
# pumpting rate: -2090.625000, penalty : 0.000000, objval: -129618.750000
# pumpting rate: -2093.750000, penalty : 25686945.232529, objval: 25557132.732529
# pumpting rate: -2093.750000, penalty : 25686945.232529, objval: 25557132.732529
# pumpting rate: -2089.062500, penalty : 0.000000, objval: -129521.875000
# pumpting rate: -2092.187500, penalty : 25629327.776643, objval: 25499612.151643
# pumpting rate: -2089.843750, penalty : 0.000000, objval: -129570.315600
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2090.234375, penalty : 0.000000, objval: -129594.532800
# pumpting rate: -2091.015625, penalty : 0.000000, objval: -129642.967200
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2090.820312, penalty : 0.000000, objval: -129630.858600
# pumpting rate: -2091.210938, penalty : 0.000000, objval: -129655.075800
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.113281, penalty : 0.000000, objval: -129649.024600
# pumpting rate: -2091.308594, penalty : 0.000000, objval: -129661.133200
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.259766, penalty : 0.000000, objval: -129658.107600
# pumpting rate: -2091.357422, penalty : 0.000000, objval: -129664.158800
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.333008, penalty : 0.000000, objval: -129662.646000
# pumpting rate: -2091.381836, penalty : 0.000000, objval: -129665.671600
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.406250, penalty : 25600555.424423, objval: 25470888.240023
# pumpting rate: -2091.369629, penalty : 0.000000, objval: -129664.915200
# <img src="data:image/png;base64,..." width="898.8889127013131">
# Water obtained is  -2091.3818359375 cubic m per day, with max drawdown of  3m

# %%
def f(Q):
    model = Fin_Mod()
    model.run(All_Qs)

    objval = Q
    minhead = model.minhead()
    if minhead <= -1.0:
        penalty = 1.e+5 * (minhead + 1.0) ** 2
        objval = objval + penalty
        print("pumpting rate: %f, penalty : %f, objval: %f" % (Q, penalty, objval))
    else:
        print("pumpting rate: %f, objval: %f" % (Q, objval))

    return objval


# Use Nelder-Mead/Simplex method for this problem
results = opt.minimize(f,x0=-50.,method="Nelder-Mead",tol = 1.e-2)
#results = opt.minimize(f,x0=-50.,method="BFGS",options={'gtol': 0.1,'disp':True,'eps': 1.e-6})



def optomizo(Q):
    model = Fin_Mod()
    model.run(Q)

    objval = Q

    observations = np.loadtxt('test_no_5.2.hob.out', skiprows=1, usecols=[0,1])
    residuals= []
    for idx, i in enumerate(observations):   
        r = observations[idx][1]-observations[idx][0]
        residuals.append(r)
    top_draw = max(residuals)
    
    rates = np.loadtxt('test_no_5.2.wel', skiprows=3, usecols=3)
    Sum_Q = sum(rates)

    if top_draw > 2:                 # this is where the maximum allwable drawdown is defined
        penalty = 1000* (top_draw + 1.0) ** 2               # this is where the penalty for exceeding maximum allwable drawdown is defined
    else: 
        penalty = 0

    cost_ben = Sum_Q + penalty
    
    return cost_ben




All_Qs = -1300
Fin_Mod().run(All_Qs)

observations = np.loadtxt('test_no_5.2.hob.out', skiprows=1, usecols=[0,1])
residuals= []
for idx, i in enumerate(observations):   
    r = observations[idx][1]-observations[idx][0]
    residuals.append(r)
top_draw = max(residuals)


rates = np.loadtxt('test_no_5.2.wel', skiprows=3, usecols=3)
Sum_Q = sum(rates)

if top_draw > 2:                 # this is where the maximum allwable drawdown is defined
    penalty = 10000000               # this is where the penalty for exceeding maximum allwable drawdown is defined
else: 
    penalty = 0

cost_ben = Sum_Q + penalty
cost_ben

print("Water obtained is  {} cubic m per day, with max drawdown of {} incliuding penalty of {}".format(Sum_Q, top_draw, penalty))
print("total cost benefit is {}".format(cost_ben))
Fin_Mod().plot()
# Out:
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:38
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -50.000000, penalty : 99600400000.000000, objval: 99600399950.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -52.500000, penalty : 99600400000.000000, objval: 99600399947.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#  Elapsed run time:  0.032 Seconds
#
#   Normal termination of simulation
# pumpting rate: -55.000000, penalty : 99600400000.000000, objval: 99600399945.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#  Elapsed run time:  0.036 Seconds
#
#   Normal termination of simulation
# pumpting rate: -57.500000, penalty : 99600400000.000000, objval: 99600399942.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:39
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#  Elapsed run time:  0.038 Seconds
#
#   Normal termination of simulation
# pumpting rate: -62.500000, penalty : 99600400000.000000, objval: 99600399937.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#  Elapsed run time:  0.040 Seconds
#
#   Normal termination of simulation
# pumpting rate: -67.500000, penalty : 99600400000.000000, objval: 99600399932.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#  Elapsed run time:  0.022 Seconds
#
#   Normal termination of simulation
# pumpting rate: -77.500000, penalty : 99600400000.000000, objval: 99600399922.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:40
#  Elapsed run time:  0.047 Seconds
#
#   Normal termination of simulation
# pumpting rate: -87.500000, penalty : 99600400000.000000, objval: 99600399912.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#  Elapsed run time:  0.041 Seconds
#
#   Normal termination of simulation
# pumpting rate: -107.500000, penalty : 99600400000.000000, objval: 99600399892.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -127.500000, penalty : 99600400000.000000, objval: 99600399872.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#  Elapsed run time:  0.034 Seconds
#
#   Normal termination of simulation
# pumpting rate: -167.500000, penalty : 99600400000.000000, objval: 99600399832.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:41
#  Elapsed run time:  0.037 Seconds
#
#   Normal termination of simulation
# pumpting rate: -207.500000, penalty : 99600400000.000000, objval: 99600399792.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#  Elapsed run time:  0.039 Seconds
#
#   Normal termination of simulation
# pumpting rate: -287.500000, penalty : 99600400000.000000, objval: 99600399712.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#  Elapsed run time:  0.028 Seconds
#
#   Normal termination of simulation
# pumpting rate: -367.500000, penalty : 99600400000.000000, objval: 99600399632.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#  Elapsed run time:  0.035 Seconds
#
#   Normal termination of simulation
# pumpting rate: -527.500000, penalty : 99600400000.000000, objval: 99600399472.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:42
#  Elapsed run time:  0.075 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -687.500000, penalty : 99600400000.000000, objval: 99600399312.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#  Elapsed run time:  0.038 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1007.500000, penalty : 99600400000.000000, objval: 99600398992.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#  Elapsed run time:  0.039 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1327.500000, penalty : 99600400000.000000, objval: 99600398672.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#  Elapsed run time:  0.032 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1967.500000, penalty : 99600400000.000000, objval: 99600398032.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:43
#  Elapsed run time:  0.038 Seconds
#
#   Normal termination of simulation
# pumpting rate: -2607.500000, penalty : 99600400000.000000, objval: 99600397392.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#  Elapsed run time:  0.047 Seconds
#
#   Normal termination of simulation
# pumpting rate: -3887.500000, penalty : 99600400000.000000, objval: 99600396112.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#  Elapsed run time:  0.039 Seconds
#
#   Normal termination of simulation
# pumpting rate: -5167.500000, penalty : 99600400000.000000, objval: 99600394832.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#  Elapsed run time:  0.079 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -7727.500000, penalty : 99600400000.000000, objval: 99600392272.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:44
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#  Elapsed run time:  0.042 Seconds
#
#   Normal termination of simulation
# pumpting rate: -10287.500000, penalty : 99600400000.000000, objval: 99600389712.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#  Elapsed run time:  0.041 Seconds
#
#   Normal termination of simulation
# pumpting rate: -15407.500000, penalty : 99600400000.000000, objval: 99600384592.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#  Elapsed run time:  0.078 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -20527.500000, penalty : 99600400000.000000, objval: 99600379472.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:45
#  Elapsed run time:  0.095 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -30767.500000, penalty : 99600400000.000000, objval: 99600369232.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#  Elapsed run time:  0.078 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -41007.500000, penalty : 99600400000.000000, objval: 99600358992.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#  Elapsed run time:  0.046 Seconds
#
#   Normal termination of simulation
# pumpting rate: -61487.500000, penalty : 99600400000.000000, objval: 99600338512.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#  Elapsed run time:  0.109 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -81967.500000, penalty : 99600400000.000000, objval: 99600318032.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:46
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:47
#  Elapsed run time:  0.116 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -122927.500000, penalty : 99600400000.000000, objval: 99600277072.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:47
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:47
#  Elapsed run time:  0.125 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -163887.500000, penalty : 99600400000.000000, objval: 99600236112.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:47
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:47
#  Elapsed run time:  0.140 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -245807.500000, penalty : 99600400000.000000, objval: 99600154192.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:47
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:48
#  Elapsed run time:  0.146 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -327727.500000, penalty : 99600400000.000000, objval: 99600072272.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:48
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:48
#  Elapsed run time:  0.145 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -491567.500000, penalty : 99600400000.000000, objval: 99599908432.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:48
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:48
#  Elapsed run time:  0.162 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -655407.500000, penalty : 99600400000.000000, objval: 99599744592.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:49
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:49
#  Elapsed run time:  0.174 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -983087.500000, penalty : 99600400000.000000, objval: 99599416912.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:49
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:49
#  Elapsed run time:  0.104 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1310767.500000, penalty : 99600400000.000000, objval: 99599089232.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:49
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:49
#  Elapsed run time:  0.084 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -1966127.500000, penalty : 99600400000.000000, objval: 99598433872.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#  Elapsed run time:  0.083 Seconds
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA            1  TIME(S)
# pumpting rate: -2621487.500000, penalty : 99600400000.000000, objval: 99597778512.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#  Elapsed run time:  0.041 Seconds
#
#   Normal termination of simulation
# pumpting rate: -3932207.500000, penalty : 99600400000.000000, objval: 99596467792.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#  Elapsed run time:  0.051 Seconds
#
#   Normal termination of simulation
# pumpting rate: -5242927.500000, penalty : 99600400000.000000, objval: 99595157072.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:50
#  Elapsed run time:  0.057 Seconds
#
#   Normal termination of simulation
# pumpting rate: -7864367.500000, penalty : 99600400000.000000, objval: 99592535632.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#  Elapsed run time:  0.034 Seconds
#
#   Normal termination of simulation
# pumpting rate: -10485807.500000, penalty : 99600400000.000000, objval: 99589914192.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#  Elapsed run time:  0.036 Seconds
#
#   Normal termination of simulation
# pumpting rate: -15728687.500000, penalty : 99600400000.000000, objval: 99584671312.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#  Elapsed run time:  0.046 Seconds
#
#   Normal termination of simulation
# pumpting rate: -20971567.500000, penalty : 99600400000.000000, objval: 99579428432.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:51
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#  Elapsed run time:  0.032 Seconds
#
#   Normal termination of simulation
# pumpting rate: -31457327.500000, penalty : 99600400000.000000, objval: 99568942672.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#  Elapsed run time:  0.033 Seconds
#
#   Normal termination of simulation
# pumpting rate: -41943087.500000, penalty : 99600400000.000000, objval: 99558456912.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#  Elapsed run time:  0.033 Seconds
#
#   Normal termination of simulation
# pumpting rate: -62914607.500000, penalty : 99600400000.000000, objval: 99537485392.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -83886127.500000, penalty : 99600400000.000000, objval: 99516513872.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:52
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#  Elapsed run time:  0.030 Seconds
#
#   Normal termination of simulation
# pumpting rate: -125829167.500000, penalty : 99600400000.000000, objval: 99474570832.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#  Elapsed run time:  0.021 Seconds
#
#   Normal termination of simulation
# pumpting rate: -167772207.500000, penalty : 99600400000.000000, objval: 99432627792.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -251658287.500000, penalty : 99600400000.000000, objval: 99348741712.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#  Elapsed run time:  0.030 Seconds
#
#   Normal termination of simulation
# pumpting rate: -335544367.500000, penalty : 99600400000.000000, objval: 99264855632.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:53
#  Elapsed run time:  0.023 Seconds
#
#   Normal termination of simulation
# pumpting rate: -503316527.500000, penalty : 99600400000.000000, objval: 99097083472.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -671088687.500000, penalty : 99600400000.000000, objval: 98929311312.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#  Elapsed run time:  0.025 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1006633007.500000, penalty : 99600400000.000000, objval: 98593766992.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#  Elapsed run time:  0.025 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1342177327.500000, penalty : 99600400000.000000, objval: 98258222672.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:54
#  Elapsed run time:  0.016 Seconds
#
#   Normal termination of simulation
# pumpting rate: -2013265967.500000, penalty : 99600400000.000000, objval: 97587134032.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -2684354607.500000, penalty : 99600400000.000000, objval: 96916045392.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#  Elapsed run time:  0.026 Seconds
#
#   Normal termination of simulation
# pumpting rate: -4026531887.500000, penalty : 99600400000.000000, objval: 95573868112.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#  Elapsed run time:  0.023 Seconds
#
#   Normal termination of simulation
# pumpting rate: -5368709167.500000, penalty : 99600400000.000000, objval: 94231690832.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:55
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -8053063727.500000, penalty : 99600400000.000000, objval: 91547336272.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -10737418287.500000, penalty : 99600400000.000000, objval: 88862981712.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -16106127407.500000, penalty : 99600400000.000000, objval: 83494272592.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#  Elapsed run time:  0.028 Seconds
#
#   Normal termination of simulation
# pumpting rate: -21474836527.500000, penalty : 99600400000.000000, objval: 78125563472.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:56
#  Elapsed run time:  0.028 Seconds
#
#   Normal termination of simulation
# pumpting rate: -32212254767.500000, penalty : 99600400000.000000, objval: 67388145232.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:57
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:57
#  Elapsed run time:  0.016 Seconds
#
#   Normal termination of simulation
# pumpting rate: -42949673007.500000, penalty : 99600400000.000000, objval: 56650726992.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:57
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:29:57
#  Elapsed run time:  0.024 Seconds
#
#   Normal termination of simulation
# pumpting rate: -64424509487.500000, penalty : 99600400000.000000, objval: 35175890512.500000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
# ...
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#  Elapsed run time:  0.019 Seconds
#
#   Normal termination of simulation
# pumpting rate: -2321137573660088015435857920.000000, penalty : 99600400000.000000, objval: -2321137573660088015435857920.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#  Elapsed run time:  0.033 Seconds
#
#   Normal termination of simulation
# pumpting rate: -3094850098213450687247810560.000000, penalty : 99600400000.000000, objval: -3094850098213450687247810560.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#  Elapsed run time:  0.032 Seconds
#
#   Normal termination of simulation
# pumpting rate: -4642275147320176030871715840.000000, penalty : 99600400000.000000, objval: -4642275147320176030871715840.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:24
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -6189700196426901374495621120.000000, penalty : 99600400000.000000, objval: -6189700196426901374495621120.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -9284550294640352061743431680.000000, penalty : 99600400000.000000, objval: -9284550294640352061743431680.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#  Elapsed run time:  0.021 Seconds
#
#   Normal termination of simulation
# pumpting rate: -12379400392853802748991242240.000000, penalty : 99600400000.000000, objval: -12379400392853802748991242240.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -18569100589280704123486863360.000000, penalty : 99600400000.000000, objval: -18569100589280704123486863360.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:25
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#  Elapsed run time:  0.026 Seconds
#
#   Normal termination of simulation
# pumpting rate: -24758800785707605497982484480.000000, penalty : 99600400000.000000, objval: -24758800785707605497982484480.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#  Elapsed run time:  0.015 Seconds
#
#   Normal termination of simulation
# pumpting rate: -37138201178561408246973726720.000000, penalty : 99600400000.000000, objval: -37138201178561408246973726720.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#  Elapsed run time:  0.027 Seconds
#
#   Normal termination of simulation
# pumpting rate: -49517601571415210995964968960.000000, penalty : 99600400000.000000, objval: -49517601571415210995964968960.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#  Elapsed run time:  0.018 Seconds
#
#   Normal termination of simulation
# pumpting rate: -74276402357122816493947453440.000000, penalty : 99600400000.000000, objval: -74276402357122816493947453440.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:26
#  Elapsed run time:  0.030 Seconds
#
#   Normal termination of simulation
# pumpting rate: -99035203142830421991929937920.000000, penalty : 99600400000.000000, objval: -99035203142830421991929937920.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -148552804714245632987894906880.000000, penalty : 99600400000.000000, objval: -148552804714245632987894906880.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -198070406285660843983859875840.000000, penalty : 99600400000.000000, objval: -198070406285660843983859875840.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#  Elapsed run time:  0.024 Seconds
#
#   Normal termination of simulation
# pumpting rate: -297105609428491265975789813760.000000, penalty : 99600400000.000000, objval: -297105609428491265975789813760.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:27
#  Elapsed run time:  0.027 Seconds
#
#   Normal termination of simulation
# pumpting rate: -396140812571321687967719751680.000000, penalty : 99600400000.000000, objval: -396140812571321687967719751680.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#  Elapsed run time:  0.029 Seconds
#
#   Normal termination of simulation
# pumpting rate: -594211218856982531951579627520.000000, penalty : 99600400000.000000, objval: -594211218856982531951579627520.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#  Elapsed run time:  0.022 Seconds
#
#   Normal termination of simulation
# pumpting rate: -792281625142643375935439503360.000000, penalty : 99600400000.000000, objval: -792281625142643375935439503360.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#  Elapsed run time:  0.023 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1188422437713965063903159255040.000000, penalty : 99600400000.000000, objval: -1188422437713965063903159255040.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:28
#  Elapsed run time:  0.037 Seconds
#
#   Normal termination of simulation
# pumpting rate: -1584563250285286751870879006720.000000, penalty : 99600400000.000000, objval: -1584563250285286751870879006720.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:29
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:29
#  Elapsed run time:  0.031 Seconds
#
#   Normal termination of simulation
# pumpting rate: -2376844875427930127806318510080.000000, penalty : 99600400000.000000, objval: -2376844875427930127806318510080.000000
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:29
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:30:29
#  Elapsed run time:  0.027 Seconds
#
#   Normal termination of simulation
# pumpting rate: -3169126500570573503741758013440.000000, penalty : 99600400000.000000, objval: -3169126500570573503741758013440.000000

# %% [markdown]
# # running the model and the optomization portion

# %%
All_Qs = -1300
Fin_Mod().run(All_Qs)

observations = np.loadtxt('test_no_5.2.hob.out', skiprows=1, usecols=[0,1])
residuals= []
for idx, i in enumerate(observations):   
    r = observations[idx][1]-observations[idx][0]
    residuals.append(r)
top_draw = max(residuals)


rates = np.loadtxt('test_no_5.2.wel', skiprows=3, usecols=3)
Sum_Q = sum(rates)

if top_draw > 2:                 # this is where the maximum allwable drawdown is defined
    penalty = 10000000               # this is where the penalty for exceeding maximum allwable drawdown is defined
else: 
    penalty = 0

cost_ben = Sum_Q + penalty
cost_ben

print("Water obtained is  {} cubic m per day, with max drawdown of {} incliuding penalty of {}".format(Sum_Q, top_draw, penalty))
print("total cost benefit is {}".format(cost_ben))
Fin_Mod().plot()
# Out:
# FloPy is using the following executable to run the model: mf2005.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.11.00 8/8/2013
#
#  Using NAME file: test_no_5.2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:25:15
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/04/26 17:25:15
#  Elapsed run time:  0.032 Seconds
#
#   Normal termination of simulation
# Water obtained is  -80600.0 cubic m per day, with max drawdown of 1.8630418777500006 incliuding penalty of 0
# total cost benefit is -80600.0
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %%
import scipy.optimize as opt
c = np.array([1.]) # minimize Q (maximize extraction); actually x0_bounds is defined for Q to be negative
# you can interpret this as head change should be smaller than allowable head change
A = np.array([[cost_ben]]) # head change at (4,4) due to pumping rate Q;
                                      # make sure this is negative due to Q < 0
                                      # this should be two dimensional array!
b = np.array([1.])                    # maximum allowable head change at (4,4)
x0_bounds = (None, 0)                 # Q <= 0
res = opt.linprog(c, A_ub=A, b_ub=b,
                  bounds=(x0_bounds),
                  options={"disp": True})
res
# Out:
# Optimization terminated successfully.
#          Current function value: -0.000012
#          Iterations: 1
#      fun: -1.2406947890818859e-05
#  message: 'Optimization terminated successfully.'
#      nit: 1
#    slack: array([0.00000000e+00, 1.24069479e-05])
#   status: 0
#  success: True
#        x: array([-1.24069479e-05])

# %%
c = np.array([1.]) # minimize Q (maximize extraction); actually x0_bounds is defined for Q to be negative
# you can interpret this as head change should be smaller than allowable head change
A = np.array([[-head_change[0,4,4]]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-b665ae9bb4dc> in <module>()
#       1 c = np.array([1.]) # minimize Q (maximize extraction); actually x0_bounds is defined for Q to be negative
#       2 # you can interpret this as head change should be smaller than allowable head change
# ----> 3 A = np.array([[-head_change[0,4,4]]])
#
# NameError: name 'head_change' is not defined

# %% [markdown]
# # stuff to keep working on
# - introduce the lin alg optomization

# %%
# this is how you would formulate the lnear algebra part of the optomization 
"""
 that can copy from
"""
import scipy.optimize as opt
from mymf_v3 import mymf
import numpy as np

# we will start with initial head = 1 m
# construct RMA
init_head = 1. # initial head
model = mymf(init_head=init_head)
well_rcs = [[4,4]]      # center
Qs = [-1.]              # unit pumping rate
model.run(well_rcs,Qs)
model.plot()

head = model.head() # note this array is 3D!
head_change = init_head - head

# minimum head should take place at the pumping well [4,4]

c = np.array([1.]) # minimize Q (maximize extraction); actually x0_bounds is defined for Q to be negative
# you can interpret this as head change should be smaller than allowable head change
A = np.array([[-head_change[0,4,4]]]) # head change at (4,4) due to pumping rate Q;
                                      # make sure this is negative due to Q < 0
                                      # this should be two dimensional array!
b = np.array([1.])                    # maximum allowable head change at (4,4)
x0_bounds = (None, 0)                 # Q <= 0
res = opt.linprog(c, A_ub=A, b_ub=b,
                  bounds=(x0_bounds),
                  options={"disp": True})

print('### result with minimal head constraint ###')
print(res)
print('the maximum pumping rate is %f' % (res.x))

# result plotting
init_head = 1. # initial head distribution = 1 m
model = mymf(init_head)
well_rcs = [[4,4]] # nrow = 10, ncol = 10
Qs = res.x # optimization solution
model.run(well_rcs,Qs)
model.plot('head at the center'
# Out:
#   File "<ipython-input-40-4c27e72ce10b>", line 44
#     model.plot('head at the center'
#                                    ^
# SyntaxError: unexpected EOF while parsing
